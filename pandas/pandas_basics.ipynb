# %%
import pandas as pd

# %% [markdown]
# Dataframe : table container

# %%
pd.DataFrame(
    {'Rooms':[1,2,1],'Bathrooms':[1,1,1],'Area':['Venice','Marseille','Paris'],'Price':[300,300,200]},
    index=['Solution 1','Solution 2','Solution 3']
)
# Out:
#             Rooms  Bathrooms       Area  Price
# Solution 1      1          1     Venice    300
# Solution 2      2          1  Marseille    300
# Solution 3      1          1      Paris    200

# %%
product = pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
product.loc["2016 Sales"]
# Out:
# 35

# %%
quantities = ['4 cups', '1 cup', '2 large', '1 can']
items = ['Flour', 'Milk', 'Eggs', 'Spam']
recipe = pd.Series(quantities, index=items, name='Dinner')
recipe
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
wine_reviews = pd.read_csv("data/winemag-data_first150k.csv",index_col=0)
# to get dimension of the table
wine_reviews.shape
# to get 5 five rows
wine_reviews.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### iloc : integer location
#
# ```
# Iloc uses standard python indexing so [0:10] will select entries from 0,...,9
# ```
#
# data.iloc[row,column]

# %%
data = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]},index=['X','Y','Z'])

selected_data = data.iloc[0:3, 0:2]
print(selected_data)
# Out:
#    A  B
# X  1  4
# Y  2  5
# Z  3  6

# %% [markdown]
# ### loc : select by dataframe label
# ```
# Loc indexing different than standard python : [0,10] will select 0,...,10
# ```

# %%
selected_data = data.loc['X':'Z', 'A':'B']
print(selected_data)
# Out:
#    A  B
# X  1  4
# Y  2  5
# Z  3  6

# %%
df = pd.DataFrame(
    {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'Salary': [50000, 60000, 70000, 80000]})

max_salary = df.Salary.max()
f_salary = df.Salary[0]

print(max_salary)
# Out:
# 80000

# %% [markdown]
# ### Conditionnal selection

# %%
sample_reviews = wine_reviews.loc[[1,2,3,5,8]]

wine_reviews.loc[wine_reviews.country == 'Spain'].head()

wine_reviews.country =="Italy"

wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.points >= 90)].head()

wine_reviews.loc[wine_reviews.country.isin(['Italy', 'France'])].head()

wine_reviews.loc[wine_reviews.price.notnull()].head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %%
indices = [0,1,10,100]
features = ['country','price','region_1','region_2']
df = pd.DataFrame(wine_reviews.loc[indices,features])
df
# Out:
#     country  price     region_1     region_2
# 0        US  235.0  Napa Valley         Napa
# 1     Spain  110.0         Toro          NaN
# 10    Italy   80.0       Collio          NaN
# 100      US   24.0  South Coast  South Coast

# %%
top_oceania_wines = wine_reviews.loc[
    (wine_reviews.points >= 95) & 
    (wine_reviews.country.isin(['Australia','New Zealand']))
]
top_oceania_wines.head(3)
# Out:
#         country                                        description  \
# 2148  Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458  Australia  This is a top example of the classic Australia...
# 3033  Australia  This Cabernet equivalent to Grange has explode...
#
#      designation  points  price         province         region_1 region_2  \
# 2148  The Factor      98  125.0  South Australia   Barossa Valley      NaN
# 2458   The Peake      96  150.0  South Australia     McLaren Vale      NaN
# 3033     Bin 707      95  500.0  South Australia  South Australia      NaN
#
#                  variety        winery
# 2148              Shiraz      Torbreck
# 2458     Cabernet-Shiraz  Hickinbotham
# 3033  Cabernet Sauvignon      Penfolds

# %% [markdown]
# ### Assigning data

# %%
wine_reviews["critic"] = 'everyone'
wine_reviews["critic"]
# Out:
# 0         everyone
# 1         everyone
# 2         everyone
# 3         everyone
# 4         everyone
#             ...
# 150925    everyone
# 150926    everyone
# 150927    everyone
# 150928    everyone
# 150929    everyone
# Name: critic, Length: 150930, dtype: object

# %% [markdown]
# # Map and groupby

# %%
wine_reviews.points.head(3)
wine_reviews.points.map(lambda p : p - 1).head(3)
# Out:
# 0    95
# 1    95
# 2    95
# Name: points, dtype: int64

# %%
rev = wine_reviews.head(5)
rev.groupby('points').points.count()
# rev
rev.groupby('points').price.min()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# ...

# %% [markdown]
# # Sorting

# %%
wine_reviews.sort_values(by='points').head(5)
# Out:
#        level_0  index country  \
# 92914    92914  92914   Spain
# 96766    96766  96766   Spain
# 96767    96767  96767   Spain
# 96768    96768  96768   Spain
# 96769    96769  96769      US
#
#                                              description  \
# 92914  Smells like canned fruit, and tastes like gree...
# 96766  There's something not right about the way this...
# 96767  This is mucky and sweet. Its best foot is not ...
# 96768  Eight grapes comprise this weird, peanutty, al...
# 96769  Port-like, with raisiny, baked cherry and cara...
#
#                          designation  points  price        province  \
# 92914  Clos Torribas Blanc de Blancs      80   10.0       Catalonia
# 96766       Gran Reserva Brut Nature      80   27.0       Catalonia
# 96767                            NaN      80    8.0  Northern Spain
# 96768                       Las Ocho      80   25.0         Levante
# 96769                  Grand Reserve      80   40.0      California
#
# ...

# %%
wine_reviews.sort_values(by=['country', 'points'])
# Out:
#         level_0   index    country  \
# 4642       4642    4642    Albania
# 4864       4864    4864    Albania
# 7793       7793    7793  Argentina
# 7794       7794    7794  Argentina
# 10533     10533   10533  Argentina
# ...         ...     ...        ...
# 68226     68226   68226        NaN
# 113016   113016  113016        NaN
# 135696   135696  135696        NaN
# 1133       1133    1133        NaN
# 1440       1440    1440        NaN
#
#                                               description     designation  \
# 4642    This garnet-colored wine made from 100% Kallme...             NaN
# 4864    This garnet-colored wine made from 100% Kallme...             NaN
# 7793    Tropical, soapy aromas are yeasty and flat. Fl...             NaN
# 7794    Candied plum and red berry aromas smell like r...  Estate Bottled
# 10533   Oily, match-stick aromas are none too friendly...          Phebus
# ...                                                   ...             ...
# ...

# %% [markdown]
# # Missing Data

# %%
wine_reviews[pd.isnull(wine_reviews.country)]

# replace Not Available data
wine_reviews.region_2.fillna("Unknown")
wine_reviews.price.replace(20.0, 22.0)
# Out:
# 0         235.0
# 1         110.0
# 2          90.0
# 3          65.0
# 4          66.0
#           ...
# 150925     22.0
# 150926     27.0
# 150927     22.0
# 150928     52.0
# 150929     15.0
# Name: price, Length: 150930, dtype: float64

# %% [markdown]
# # Renaming and combining

# %%
wine_reviews.rename(columns={'points': 'score'})
wine_reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})

# %%
canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")


left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK')
